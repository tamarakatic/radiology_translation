# %%
from numpy import genfromtxt
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %matplotlib inline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

# %%
sentences = pd.read_csv('../data/processed/temple_radio_1_2_sentences_with_translation.csv')
sent_embeddings = genfromtxt('../data/processed/temple_radio_1_2_sentence_embeddings.csv', delimiter=',')

# %%
pos_sent = sentences[sentences['Translation'] == 'There is increased amount of fat in the liver.']

# %%
pos_sent_embeddings = sent_embeddings[pos_sent.index, :]
neg_sent = sentences.drop(pos_sent.index)
neg_sent_embeddings = sent_embeddings[neg_sent.index, :]

# %%
neg_sent_embeddings = sent_embeddings[neg_sent.index, :]

# %%
pos_sent = pos_sent.reset_index(drop=True)
neg_sent = neg_sent.reset_index(drop=True)

# %%
new_sent_df = pd.concat([pos_sent, neg_sent]).reset_index(drop=True)

# %%
y_pos = [1 for p in range(len(pos_sent_embeddings))]
y_neg = [0 for n in range(len(neg_sent_embeddings))]

pos_df = pd.DataFrame(pos_sent_embeddings)
pos_df['class'] = y_pos

neg_df = pd.DataFrame(neg_sent_embeddings)
neg_df['class'] = y_neg

pos_df = pos_df.reset_index(drop=True)
neg_df = neg_df.reset_index(drop=True)

new_df = pd.concat([pos_df, neg_df]).reset_index(drop=True)

# %%
new_df['sentence'] = new_sent_df['Sentence']
new_df['translation'] = new_sent_df['Translation']

# %%
new_df = new_df.sample(frac=1).reset_index(drop=True)

# %%
y = new_df[["class"]]
X = new_df.drop(["class"], axis = 1)

# %%
skf = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
acc_scores, f1_scores = [], []
i = 0
conf_scores = []

for train, test in skf.split(X, y): # Provides train/test indices to split data in train/test sets.
    clf = LogisticRegression(random_state=0, max_iter=1000).fit(X.drop(["sentence", "translation"], axis = 1).loc[train], y.loc[train].values.ravel())
    y_pred = clf.predict(X.drop(["sentence", "translation"], axis = 1).loc[test])
    
    df_skf = pd.DataFrame(X[['sentence', 'translation']].loc[test])
 
    df_skf['y_true'] = y.loc[test]
    df_skf['pred'] = y_pred
    df_skf.to_csv(f"../data/processed/classification_results/second_result_{i}.csv", index=False)
    
    acc = accuracy_score(y.loc[test], y_pred)
    f1 = f1_score(y.loc[test], y_pred)
    acc_scores.append(round(acc, 4))
    f1_scores.append(round(f1, 4))
    conf_scores.append(confusion_matrix(y.loc[test], y_pred))
    i += 1
print(f"confusion matrix score:\n{sum(conf_scores)}")
# Out:
# confusion matrix score:
# [[225   1]
#  [  6  18]]

# %%
print(f"Acc scores: {acc_scores}\nMean acc: {sum(acc_scores)/len(acc_scores):.4f}\n")
print(f"F1 scores: {f1_scores}\nMean f1: {sum(f1_scores)/len(f1_scores):.4f}\n")
# Out:
# Acc scores: [1.0, 0.98, 0.98, 0.98, 0.92]
# Mean acc: 0.9720
#
# F1 scores: [1.0, 0.8889, 0.8889, 0.9091, 0.3333]
# Mean f1: 0.8040

# %%
df = pd.read_csv("../data/processed/classification_results/second_result_0.csv")

# %%
df
# Out:
#                                              sentence  \
# 0                     with diffuse hepatic steatosis.
# 1                               Smooth liver contour.
# 2   Evaluation of the liver, particularly the, pos...
# 3                    with diffuse fatty infiltration.
# 4   There is a 1.4 cm cyst at the right hepatic dome.
# 5   Normal, in size, measuring 14.0 cm in cranioca...
# 6   Normal in contour and enhancement without foca...
# 7   Evidence of a subcapsular left lobe segment 2,...
# 8   Subcentimeter hypoattenuating lesion within th...
# 9               No definite, suspicious focal lesion.
# 10  Liver measures 17 cm in craniocaudal dimension...
# 11  No intrahepatic or extrahepatic, biliary dilat...
# 12  Liver is enlarged measuring 21.6 cm in cranioc...
# 13  Uniformly isoattenuating liver, and spleen and...
# 14  Evidence of an irregular enhancing, space-occu...
# 15                           No focal hepatic lesion.
# 16                        Diffuse hepatic steatosis .
# 17  Overall, lesions, appear stable compared to pr...
# 18  Subcentimeter, hypoattenuating lesion in segme...
# 19                                    Normal in size.
# 20  No definite suspicious focal mass within the l...
# 21                              No new, liver lesion.
# 22  Subcentimeter hypodensity at the, dome of the ...
# 23                         Liver is mildly enlarged .
# 24                         Homogenous in attenuation.
# 25  There is a 2.3 x 2 cm posterior right hepatic,...
# 26  Subcentimeter hypodense foci seen within the l...
# 27            Normal size with a few scattered cysts.
# 28            No other focal parenchymal abnormality.
# 29  The liver is of normal size with homogenous pa...
# 30    Nodular surface contour keeping with cirrhosis.
# 31  Redemonstrated metastatic lesions throughout t...
# 32                     Liver normal size and contour.
# 33  Lesion in, segment VIII measures 1.5 x 1.4 cm ...
# 34  Redemonstrated scattered hepatic cysts, better...
# 35  Liver, is normal size, measuring 16.0 cm in cr...
# 36  Calcified granuloma in the inferior right, hep...
# 37  Normal in contour and enhancement with no foca...
# 38    with, numerous rounded foci of hypoenhancement.
# 39  Subcentimeter hypodense, lesion in the left lo...
# 40  Heterogeneous, liver parenchyma with liver sur...
# 41          Homogenous without suspicious focal mass.
# 42                Probable diffuse hepatic steatosis.
# 43                 Normal in contour and attenuation.
# 44   Hepatomegaly, 19.1 cm in craniocaudal long axis.
# 45      Visualized portions are grossly unremarkable.
# 46                                 Normal in contour.
# 47                             Mild periportal edema.
# 48  Probable surface nodularity likely indicating ...
# 49                     Mild diffuse periportal edema.
#
#                                           translation  y_true  pred
# 0     There is increased amount of fat in the liver.        1     1
# 1                                               empty       0     0
# 2                                               empty       0     0
# 3     There is increased amount of fat in the liver.        1     1
# 4   There are one or more cysts in the liver, whic...       0     0
# 5                                               empty       0     0
# 6                                               empty       0     0
# 7                    There is an injury to the liver.       0     0
# 8   There are one or more lesions in the liver tha...       0     0
# 9                                               empty       0     0
# 10                                              empty       0     0
# 11                                              empty       0     0
# 12                             The liver is enlarged.       0     0
# 13                                              empty       0     0
# 14        There are one or more lesions in the liver.       0     0
# 15                                              empty       0     0
# 16    There is increased amount of fat in the liver.        1     1
# 17                                              empty       0     0
# 18  There are one or more lesions in the liver tha...       0     0
# 19                                              empty       0     0
# 20                                              empty       0     0
# 21                                              empty       0     0
# 22  There are one or more lesions in the liver tha...       0     0
# 23                             The liver is enlarged.       0     0
# 24                                              empty       0     0
# 25        There are one or more lesions in the liver.       0     0
# 26  There are one or more lesions in the liver tha...       0     0
# 27  There are one or more cysts in the liver, whic...       0     0
# 28                                              empty       0     0
# 29                                              empty       0     0
# 30  The liver shows bumpy/nodular surface, which c...       0     0
# 31         There are one or more masses in the liver.       0     0
# 32                                              empty       0     0
# 33                                              empty       0     0
# 34  There are one or more cysts in the liver, whic...       0     0
# 35                                              empty       0     0
# 36  There is/are benign calcification(s) in the li...       0     0
# 37                                              empty       0     0
# 38        There are one or more lesions in the liver.       0     0
# 39  There are one or more lesions in the liver tha...       0     0
# 40  The liver shows bumpy/nodular surface, which c...       0     0
# 41                                              empty       0     0
# 42    There is increased amount of fat in the liver.        1     1
# 43                                              empty       0     0
# 44                             The liver is enlarged.       0     0
# 45                                              empty       0     0
# 46                                              empty       0     0
# 47                                              empty       0     0
# 48  The liver shows bumpy/nodular surface, which c...       0     0
# 49                                              empty       0     0
