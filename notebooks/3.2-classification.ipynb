# %%
from numpy import genfromtxt
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %matplotlib inline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

# %%
sentences = pd.read_csv('../data/processed/temple_radio_1_2_sentences_with_translation.csv')
sent_embeddings = genfromtxt('../data/processed/temple_radio_1_2_sentence_embeddings.csv', delimiter=',')

# %%
pos_sent = sentences[sentences['Translation'] == 'The liver shows bumpy/nodular surface, which can be seen with cirrhosis. ']

# %%
pos_sent_embeddings = sent_embeddings[pos_sent.index, :]
neg_sent = sentences.drop(pos_sent.index)
neg_sent_embeddings = sent_embeddings[neg_sent.index, :]

# %%
neg_sent_embeddings = sent_embeddings[neg_sent.index, :]

# %%
pos_sent = pos_sent.reset_index(drop=True)
neg_sent = neg_sent.reset_index(drop=True)

# %%
new_sent_df = pd.concat([pos_sent, neg_sent]).reset_index(drop=True)

# %%
y_pos = [1 for p in range(len(pos_sent_embeddings))]
y_neg = [0 for n in range(len(neg_sent_embeddings))]

pos_df = pd.DataFrame(pos_sent_embeddings)
pos_df['class'] = y_pos

neg_df = pd.DataFrame(neg_sent_embeddings)
neg_df['class'] = y_neg

pos_df = pos_df.reset_index(drop=True)
neg_df = neg_df.reset_index(drop=True)

new_df = pd.concat([pos_df, neg_df]).reset_index(drop=True)

# %%
new_df['sentence'] = new_sent_df['Sentence']
new_df['translation'] = new_sent_df['Translation']

# %%
new_df = new_df.sample(frac=1).reset_index(drop=True)

# %%
y = new_df[["class"]]
X = new_df.drop(["class"], axis = 1)

# %%
skf = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
acc_scores, f1_scores = [], []
i = 0
conf_scores = []

for train, test in skf.split(X, y): # Provides train/test indices to split data in train/test sets.
    clf = LogisticRegression(random_state=0, max_iter=1000).fit(X.drop(["sentence", "translation"], axis = 1).loc[train], y.loc[train].values.ravel())
    y_pred = clf.predict(X.drop(["sentence", "translation"], axis = 1).loc[test])
    
    df_skf = pd.DataFrame(X[['sentence', 'translation']].loc[test])
 
    df_skf['y_true'] = y.loc[test]
    df_skf['pred'] = y_pred
    df_skf.to_csv(f"../data/processed/classification_results/third_result_{i}.csv", index=False)
    
    acc = accuracy_score(y.loc[test], y_pred)
    f1 = f1_score(y.loc[test], y_pred)
    acc_scores.append(round(acc, 4))
    f1_scores.append(round(f1, 4))
    conf_scores.append(confusion_matrix(y.loc[test], y_pred))
    i += 1
print(f"confusion matrix score:\n{sum(conf_scores)}")
# Out:
# confusion matrix score:
# [[236   0]
#  [  2  12]]

# %%
print(f"Acc scores: {acc_scores}\nMean acc: {sum(acc_scores)/len(acc_scores):.4f}\n")
print(f"F1 scores: {f1_scores}\nMean f1: {sum(f1_scores)/len(f1_scores):.4f}\n")
# Out:
# Acc scores: [1.0, 1.0, 1.0, 0.98, 0.98]
# Mean acc: 0.9920
#
# F1 scores: [1.0, 1.0, 1.0, 0.8, 0.8]
# Mean f1: 0.9200

# %%
df = pd.read_csv("../data/processed/classification_results/third_result_1.csv")

# %%
df
# Out:
#                                              sentence  \
# 0   Few stable less than 5 mm hypodensities, too, ...
# 1   Stable 1 cm laceration at the, posterior aspec...
# 2                               Hepatic veins patent.
# 3    No discrete lesions identified within the liver.
# 4   Normal in size and contour with scattered hepa...
# 5   Nodular hepatic surface contour reflecting, ch...
# 6   There is a hepatic lesion in the caudate lobe ...
# 7            No other focal, parenchymal abnormality.
# 8   Features of left hepatectomy noted., The right...
# 9                            Normal size and contour.
# 10  Severe diffuse hepatic steatosis with some fat...
# 11  Small cystic-appearing lesion between segment ...
# 12          Homogenous without suspicious focal mass.
# 13  Stable, ill-defined wedge-shaped hypodense les...
# 14  Calcination within the liver likely representi...
# 15                    with diffuse hepatic steatosis.
# 16                   with diffuse fatty infiltration.
# 17  Liver is enlarged measuring 17.8 cm in cranioc...
# 18                              No new, liver lesion.
# 19                           Mild, hepatic steatosis.
# 20  There is a relatively well-defined hypodense, ...
# 21  Stable 3.2 x 2.9 cm cyst in hepatic segment VI...
# 22  No definite suspicious lesion within the limit...
# 23  Mildly enlarged measuring 18.1 cm in craniocau...
# 24  Probable surface nodularity likely indicating ...
# 25  Normal in contour and enhancement with no foca...
# 26              Smooth liver contour., No focal mass.
# 27  Diffusely heterogeneous parenchymal enhancemen...
# 28                        Liver is normal in contour.
# 29                                   Scattered cysts.
# 30  Homogenous in attenuation with no focal parenc...
# 31                                     No focal mass.
# 32                                      Unremarkable.
# 33            Normal size with a few scattered cysts.
# 34  Normal in size, measuring 17.7 cm in craniocau...
# 35  No discrete space-occupying lesions or acute a...
# 36  Diffuse decreased attenuation which can be see...
# 37  The liver is of normal size with homogenous pa...
# 38    Nodular surface contour keeping with cirrhosis.
# 39  No intrahepatic or extrahepatic biliary, dilat...
# 40  A 1.2 cm hypodense lesion in the left hepatic ...
# 41  Subcentimeter hypodensity adjacent to the gall...
# 42  The liver is homogenously hypodense suggestive...
# 43      Liver measures 12.8 cm in critical long axis.
# 44  Normal in contour and enhancement without foca...
# 45                         No focal traumatic lesion.
# 46  Scattered hypoattenuating areas likely, small ...
# 47  13 mm hyperenhancing focus within the inferior...
# 48  There is, impression on the liver from the dia...
# 49                 Normal in contour and enhancement.
#
#                                           translation  y_true  pred
# 0   There are one or more lesions in the liver tha...       0     0
# 1                    There is an injury to the liver.       0     0
# 2                                               empty       0     0
# 3                                               empty       0     0
# 4   There are one or more lesions in the liver, so...       0     0
# 5   The liver shows bumpy/nodular surface, which c...       1     1
# 6   There is a benign mass in the liver which does...       0     0
# 7                                               empty       0     0
# 8       There are post surgical changes of the liver.       0     0
# 9                                               empty       0     0
# 10    There is increased amount of fat in the liver.        0     0
# 11  There are one or more lesions in the liver tha...       0     0
# 12                                              empty       0     0
# 13        There are one or more lesions in the liver.       0     0
# 14  There is/are benign calcification(s) in the li...       0     0
# 15    There is increased amount of fat in the liver.        0     0
# 16    There is increased amount of fat in the liver.        0     0
# 17                             The liver is enlarged.       0     0
# 18                                              empty       0     0
# 19                                              empty       0     0
# 20         There are one or more masses in the liver.       0     0
# 21  There are one or more lesions in the liver, so...       0     0
# 22                                              empty       0     0
# 23                             The liver is enlarged.       0     0
# 24  The liver shows bumpy/nodular surface, which c...       1     1
# 25                                              empty       0     0
# 26                                              empty       0     0
# 27         There are one or more masses in the liver.       0     0
# 28                                              empty       0     0
# 29  There are one or more cysts in the liver, whic...       0     0
# 30                                              empty       0     0
# 31                                              empty       0     0
# 32                                              empty       0     0
# 33  There are one or more cysts in the liver, whic...       0     0
# 34                                              empty       0     0
# 35                                              empty       0     0
# 36    There is increased amount of fat in the liver.        0     0
# 37                                              empty       0     0
# 38  The liver shows bumpy/nodular surface, which c...       1     1
# 39                                              empty       0     0
# 40        There are one or more lesions in the liver.       0     0
# 41  There are one or more lesions in the liver tha...       0     0
# 42    There is increased amount of fat in the liver.        0     0
# 43                                              empty       0     0
# 44                                              empty       0     0
# 45                                              empty       0     0
# 46  There are one or more lesions in the liver tha...       0     0
# 47        There are one or more lesions in the liver.       0     0
# 48                                              empty       0     0
# 49                                              empty       0     0
